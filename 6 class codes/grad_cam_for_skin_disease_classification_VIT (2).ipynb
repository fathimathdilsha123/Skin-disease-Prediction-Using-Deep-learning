# %% [markdown]
# # Load the Data set in to working directory

# %%
# Step 1: Install the Kaggle and KaggleHub libraries
# ------------------------------------------------------------------------------
# We use pip to install the necessary packages.
# !pip install -q kaggle kagglehub torchinfo

#==============================================================================
#  Part 2: Download the 'Dermnet' dataset using KaggleHub and Save to Drive
# ==============================================================================
# We will use the modern kagglehub library to download the dataset.
# It downloads to a local cache, and then we'll copy it to Google Drive.

import kagglehub
import os
import shutil

print("Downloading 'Dermnet' dataset with kagglehub...")
# This downloads the dataset to a temporary cache location and returns the path.
# The files are automatically unzipped.
cached_path = kagglehub.dataset_download("shubhamgoel27/dermnet")
print(f"Dataset downloaded to cache: {cached_path}")

# Define the path in your Google Drive where you want to save the dataset
working_path = '/content/Skin_desease_classification/dermnet'

os.makedirs(working_path, exist_ok=True)

# Now, we copy the files from the cache to your persistent Google Drive folder.
print(f"Copying dataset from cache to your directory at: {working_path}")

# Define the required classes
required_classes = ["Nail Fungus and other Nail Disease",
"Hair Loss Photos Alopecia and other Hair Diseases",
"Melanoma Skin Cancer Nevi and Moles",
"Vasculitis Photos"]

# Define the subdirectories within the cached path that contain the image classes
subdirs_to_copy_from = ["test", "train"]

for subdir in subdirs_to_copy_from:
    source_subdir_path = os.path.join(cached_path, subdir)
    destination_subdir_path = os.path.join(working_path, subdir)

    # Create the destination subdirectory
    os.makedirs(destination_subdir_path, exist_ok=True)

    if os.path.isdir(source_subdir_path):
        print(f"Processing subdirectory: {subdir}")
        # Loop through all items within the subdirectory
        for item in os.listdir(source_subdir_path):
            source_item = os.path.join(source_subdir_path, item)
            destination_item = os.path.join(destination_subdir_path, item)

            # Only copy if the item is a directory and is in the required_classes list
            if os.path.isdir(source_item) and item in required_classes:
                print(f"  Copying class: {item}")
                # Use copytree for directories
                shutil.copytree(source_item, destination_item, dirs_exist_ok=True)
            elif not os.path.isdir(source_item):
                 # Copy files (like metadata files) directly
                 shutil.copy2(source_item, destination_item)


print("\nSubset of Dataset successfully stored in your working directory!")
# Out:
# Downloading 'Dermnet' dataset with kagglehub...
# Dataset downloaded to cache: /kaggle/input/dermnet
# Copying dataset from cache to your directory at: /content/Skin_desease_classification/dermnet
# Processing subdirectory: test
#   Copying class: Hair Loss Photos Alopecia and other Hair Diseases
#   Copying class: Melanoma Skin Cancer Nevi and Moles
#   Copying class: Nail Fungus and other Nail Disease
#   Copying class: Vasculitis Photos
# Processing subdirectory: train
#   Copying class: Hair Loss Photos Alopecia and other Hair Diseases
#   Copying class: Melanoma Skin Cancer Nevi and Moles
#   Copying class: Nail Fungus and other Nail Disease
#   Copying class: Vasculitis Photos
#
# Subset of Dataset successfully stored in your working directory!

# %%
try:
    from going_modular.going_modular import data_setup, engine
except:
    # Get the going_modular scripts
    print("[INFO] Couldn't find going_modular scripts... downloading them from GitHub.")
    # !git clone https://github.com/mrdbourke/pytorch-deep-learning
    # !mv pytorch-deep-learning/going_modular .
    # !rm -rf pytorch-deep-learning
    from going_modular.going_modular import data_setup, engine
# Out:
# [INFO] Couldn't find going_modular scripts... downloading them from GitHub.
# Cloning into 'pytorch-deep-learning'...
# remote: Enumerating objects: 4393, done.
# remote: Total 4393 (delta 0), reused 0 (delta 0), pack-reused 4393 (from 1)
# Receiving objects: 100% (4393/4393), 764.14 MiB | 26.56 MiB/s, done.
# Resolving deltas: 100% (2656/2656), done.
# Updating files: 100% (248/248), done.

# %%
import os
import shutil
from pathlib import Path


def create_subset_of_data(source_dir, destination_dir, num_images_per_class=200):

  # Create destination directory if it doesn't exist
  os.makedirs(destination_dir, exist_ok=True)

  # Loop through each class folder
  for class_folder in os.listdir(source_dir):
      source_class_path = os.path.join(source_dir, class_folder)
      dest_class_path = os.path.join(destination_dir, class_folder)

      # Only proceed if it is a directory
      if os.path.isdir(source_class_path):
          os.makedirs(dest_class_path, exist_ok=True)

          # List image files and take the first num_images_per_class
          image_files = [f for f in os.listdir(source_class_path) if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
          selected_images = image_files[:num_images_per_class]

          # Copy selected images
          for img_file in selected_images:
              src_path = os.path.join(source_class_path, img_file)
              dst_path = os.path.join(dest_class_path, img_file)
              shutil.copy(src_path, dst_path)

  print("✅ Subset creation completed successfully!")

# %%
# Source and destination paths for train data
source_dir = "/content/Skin_desease_classification/dermnet/train"
destination_dir = "/content/Skin_desease_classification/dermnet/sub_dermanet/train"

create_subset_of_data(source_dir, destination_dir, num_images_per_class=200)
# Out:
# ✅ Subset creation completed successfully!

# %%
def get_files_list(data_path):

  classes=os.listdir(data_path)
  dic={}
  for i in classes:
      dic[i]= len(os.listdir(os.path.join(data_path,i)))
  print(f"{'=' * 10} Total Classes {len(dic.keys())} {'=' * 10} \n")
  for key,value in dic.items():
      print(key,":",value,"\n")
  return dic

# %%
_ = get_files_list(destination_dir)
# Out:
# ========== Total Classes 4 ==========
#
# Nail Fungus and other Nail Disease : 200
#
# Melanoma Skin Cancer Nevi and Moles : 200
#
# Vasculitis Photos : 200
#
# Hair Loss Photos Alopecia and other Hair Diseases : 200

# %%
# Source and destination paths for train data
source_dir = "/content/Skin_desease_classification/dermnet/test"
destination_dir = "/content/Skin_desease_classification/dermnet/sub_dermanet/test"

create_subset_of_data(source_dir, destination_dir, num_images_per_class=20)
# Out:
# ✅ Subset creation completed successfully!

# %%
_ = get_files_list(destination_dir)
# Out:
# ========== Total Classes 4 ==========
#
# Nail Fungus and other Nail Disease : 20
#
# Melanoma Skin Cancer Nevi and Moles : 20
#
# Vasculitis Photos : 20
#
# Hair Loss Photos Alopecia and other Hair Diseases : 20

# %%
# Source and destination paths for train data
train_dir = "/content/Skin_desease_classification/dermnet/sub_dermanet/train"
test_dir = "/content/Skin_desease_classification/dermnet/sub_dermanet/test"

# %%
# ===== Imports =====
import os, glob, math, random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import matplotlib.cm as cm

print(tf.__version__)
# Out:
# 2.19.0

# %%
assert os.path.isdir(train_dir) and os.path.isdir(test_dir), "Check your train/test directory paths."

# %%
# ===== Hyperparameters (copied from reference) =====
learning_rate = 1e-4 #0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 60  # reference trained 60 in experiment()

# Reference image/patch sizing (12x12 patches -> 256//20==12)
image_size = 256
patch_size = 20
num_patches = (image_size // patch_size) ** 2
projection_dim = 128
num_heads = 6
transformer_units = [projection_dim * 2, projection_dim]  # MLP size in transformer
transformer_layers = 3
mlp_head_units = [256]

# You have 4 classes
num_classes = 4
input_shape = (image_size, image_size, 3)

# %%
# ===== Data (directory-based) =====
# We create train/val split from the train directory, plus a test set from TEST_DIR
seed = 1337

train_loader = keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="training",
    seed=seed,
    image_size=(image_size, image_size),
    batch_size=batch_size,
    label_mode="categorical"
)

val_loader = keras.preprocessing.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="validation",
    seed=seed,
    image_size=(image_size, image_size),
    batch_size=batch_size,
    label_mode="categorical"
)

test_loader = keras.preprocessing.image_dataset_from_directory(
    train_dir,
    image_size=(image_size, image_size),
    batch_size=batch_size,
    shuffle=False,
    label_mode="categorical"
)

class_names = train_loader.class_names
print("Classes:", class_names)

# Prefetch for speed
AUTOTUNE = tf.data.AUTOTUNE
train_loader = train_loader.prefetch(AUTOTUNE)
val_loader   = val_loader.prefetch(AUTOTUNE)
test_loader  = test_loader.prefetch(AUTOTUNE)
# Out:
# Found 800 files belonging to 4 classes.
# Using 640 files for training.
# Found 800 files belonging to 4 classes.
# Using 160 files for validation.
# Found 800 files belonging to 4 classes.
# Classes: ['Hair Loss Photos Alopecia and other Hair Diseases', 'Melanoma Skin Cancer Nevi and Moles', 'Nail Fungus and other Nail Disease', 'Vasculitis Photos']

# %%
from tensorflow import keras
from tensorflow.keras import layers

data_augmentation = keras.Sequential([
    layers.Resizing(image_size, image_size),
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.02),
    layers.RandomZoom(0.1),
])

# %%
# ===== Helpers from reference =====
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

class PatchEncoder(layers.Layer):
    def __init__(self, num_of_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encode = self.projection(patch) + self.position_embedding(positions)
        return encode

# %%
# ===== ViT model (mirrors reference) =====
def vit_model():
    inputs = layers.Input(shape=input_shape)

    # Augment
    augmented = data_augmentation(inputs)
    # Create & encode patches
    patches = Patches(patch_size)(augmented)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Transformer blocks
    for _ in range(transformer_layers):
        # Norm
        x1 = layers.BatchNormalization()(encoded_patches)
        # MHA
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip
        x2 = layers.Add()([attention_output, encoded_patches])
        # MLP
        x3 = layers.BatchNormalization()(x2)
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip
        encoded_patches = layers.Add()([x3, x2])

    # Head
    representation = layers.LayerNormalization(name="layer_normalization")(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    logits = layers.Dense(num_classes, activation="softmax")(features)  # keep as in reference

    model = keras.Model(inputs=inputs, outputs=logits, name="vit_reference_style")
    return model

vit_classifier = vit_model()
vit_classifier.summary()
# Out:
# Model: "vit_reference_style"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 256, 256,  │          0 │ input_layer[0][0] │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patches (Patches)   │ (None, None,      │          0 │ sequential[0][0]  │
# │                     │ 1200)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ patch_encoder       │ (None, 144, 128)  │    172,160 │ patches[0][0]     │
# │ (PatchEncoder)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 144, 128)  │        512 │ patch_encoder[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 128)  │    395,648 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 144, 128)  │          0 │ multi_head_atten… │
# │                     │                   │            │ patch_encoder[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 144, 128)  │        512 │ add[0][0]         │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 144, 256)  │     33,024 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 144, 256)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 144, 128)  │     32,896 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 144, 128)  │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 144, 128)  │          0 │ dropout_2[0][0],  │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 144, 128)  │        512 │ add_1[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 128)  │    395,648 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 144, 128)  │          0 │ multi_head_atten… │
# │                     │                   │            │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 144, 128)  │        512 │ add_2[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 144, 256)  │     33,024 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 144, 256)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 144, 128)  │     32,896 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 144, 128)  │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 144, 128)  │          0 │ dropout_5[0][0],  │
# │                     │                   │            │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 144, 128)  │        512 │ add_3[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 144, 128)  │    395,648 │ batch_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 144, 128)  │          0 │ multi_head_atten… │
# │                     │                   │            │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 144, 128)  │        512 │ add_4[0][0]       │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 144, 256)  │     33,024 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 144, 256)  │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 144, 128)  │     32,896 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 144, 128)  │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 144, 128)  │          0 │ dropout_8[0][0],  │
# │                     │                   │            │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 144, 128)  │        256 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 18432)     │          0 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 18432)     │          0 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 256)       │  4,718,848 │ dropout_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 256)       │          0 │ dense_7[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 4)         │      1,028 │ dropout_10[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 6,280,068 (23.96 MB)
#  Trainable params: 6,278,532 (23.95 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
from tensorflow.keras.optimizers import AdamW

# ===== Training (reference 'experiment' function) =====
def experiment(model):
    optimizer = AdamW(learning_rate=1e-4, weight_decay=1e-4)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(from_logits=True),  # reference used from_logits=True
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.AUC(name="AUC"),
        ],
    )
    checkpoint_filepath = "/tmp/checkpoint.weights.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        mode="max",
        save_best_only=True,
        save_weights_only=True,
    )
    history = model.fit(
        train_loader,
        epochs=num_epochs,
        validation_data=val_loader,
        callbacks=[checkpoint_callback],
    )
    model.load_weights(checkpoint_filepath)
    _, accuracy, auc = model.evaluate(test_loader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test AUC: {round(auc * 100, 2)}%")
    return history

# %%
history = experiment(vit_classifier)  # Uncomment to train
# Out:
# Epoch 1/60
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:675: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 24s 162ms/step - AUC: 0.5233 - accuracy: 0.2832 - loss: 3.2835 - val_AUC: 0.5905 - val_accuracy: 0.3375 - val_loss: 1.3479
# Epoch 2/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - AUC: 0.5573 - accuracy: 0.2957 - loss: 1.6026 - val_AUC: 0.5391 - val_accuracy: 0.2625 - val_loss: 1.3804
# Epoch 3/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 180ms/step - AUC: 0.5856 - accuracy: 0.3306 - loss: 1.3752 - val_AUC: 0.6401 - val_accuracy: 0.4062 - val_loss: 1.3399
# Epoch 4/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 179ms/step - AUC: 0.5749 - accuracy: 0.2996 - loss: 1.3686 - val_AUC: 0.5648 - val_accuracy: 0.3063 - val_loss: 1.3517
# Epoch 5/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - AUC: 0.5673 - accuracy: 0.3186 - loss: 1.3841 - val_AUC: 0.5960 - val_accuracy: 0.3625 - val_loss: 1.3440
# Epoch 6/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - AUC: 0.6167 - accuracy: 0.3677 - loss: 1.2977 - val_AUC: 0.6332 - val_accuracy: 0.3500 - val_loss: 1.3079
# Epoch 7/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - AUC: 0.5988 - accuracy: 0.3358 - loss: 1.3344 - val_AUC: 0.6334 - val_accuracy: 0.3438 - val_loss: 1.3125
# Epoch 8/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - AUC: 0.6492 - accuracy: 0.3723 - loss: 1.2825 - val_AUC: 0.6314 - val_accuracy: 0.3562 - val_loss: 1.3007
# Epoch 9/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - AUC: 0.6368 - accuracy: 0.3478 - loss: 1.2959 - val_AUC: 0.6182 - val_accuracy: 0.3125 - val_loss: 1.3293
# Epoch 10/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 190ms/step - AUC: 0.6246 - accuracy: 0.3477 - loss: 1.3199 - val_AUC: 0.6947 - val_accuracy: 0.4375 - val_loss: 1.2739
# Epoch 11/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 203ms/step - AUC: 0.6415 - accuracy: 0.3698 - loss: 1.2823 - val_AUC: 0.6450 - val_accuracy: 0.3938 - val_loss: 1.3044
# Epoch 12/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - AUC: 0.6543 - accuracy: 0.3886 - loss: 1.2695 - val_AUC: 0.6467 - val_accuracy: 0.3875 - val_loss: 1.2976
# Epoch 13/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - AUC: 0.6793 - accuracy: 0.3878 - loss: 1.2537 - val_AUC: 0.6384 - val_accuracy: 0.3812 - val_loss: 1.2955
# Epoch 14/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 234ms/step - AUC: 0.6659 - accuracy: 0.3887 - loss: 1.2448 - val_AUC: 0.6405 - val_accuracy: 0.3875 - val_loss: 1.3080
# Epoch 15/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - AUC: 0.6730 - accuracy: 0.3801 - loss: 1.2600 - val_AUC: 0.6983 - val_accuracy: 0.4437 - val_loss: 1.2678
# Epoch 16/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - AUC: 0.6847 - accuracy: 0.3967 - loss: 1.2327 - val_AUC: 0.6853 - val_accuracy: 0.4062 - val_loss: 1.2770
# Epoch 17/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 196ms/step - AUC: 0.6777 - accuracy: 0.3969 - loss: 1.2513 - val_AUC: 0.7019 - val_accuracy: 0.4313 - val_loss: 1.2554
# Epoch 18/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - AUC: 0.6889 - accuracy: 0.3946 - loss: 1.2044 - val_AUC: 0.6897 - val_accuracy: 0.4375 - val_loss: 1.2443
# Epoch 19/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 204ms/step - AUC: 0.6937 - accuracy: 0.3922 - loss: 1.2082 - val_AUC: 0.7218 - val_accuracy: 0.4875 - val_loss: 1.2351
# Epoch 20/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - AUC: 0.7078 - accuracy: 0.4359 - loss: 1.1983 - val_AUC: 0.6994 - val_accuracy: 0.4062 - val_loss: 1.2406
# Epoch 21/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - AUC: 0.6944 - accuracy: 0.3873 - loss: 1.2195 - val_AUC: 0.7224 - val_accuracy: 0.4625 - val_loss: 1.2546
# Epoch 22/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - AUC: 0.6895 - accuracy: 0.4018 - loss: 1.2338 - val_AUC: 0.7220 - val_accuracy: 0.4875 - val_loss: 1.2310
# Epoch 23/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - AUC: 0.7141 - accuracy: 0.4562 - loss: 1.2022 - val_AUC: 0.6917 - val_accuracy: 0.4313 - val_loss: 1.2490
# Epoch 24/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 167ms/step - AUC: 0.6983 - accuracy: 0.3814 - loss: 1.2086 - val_AUC: 0.6990 - val_accuracy: 0.4375 - val_loss: 1.2658
# Epoch 25/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - AUC: 0.7566 - accuracy: 0.4949 - loss: 1.1305 - val_AUC: 0.7376 - val_accuracy: 0.5000 - val_loss: 1.1965
# Epoch 26/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - AUC: 0.7242 - accuracy: 0.4393 - loss: 1.1812 - val_AUC: 0.7195 - val_accuracy: 0.4750 - val_loss: 1.2178
# Epoch 27/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - AUC: 0.7490 - accuracy: 0.4766 - loss: 1.1435 - val_AUC: 0.7268 - val_accuracy: 0.4750 - val_loss: 1.2057
# Epoch 28/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 156ms/step - AUC: 0.6913 - accuracy: 0.4423 - loss: 1.2346 - val_AUC: 0.7377 - val_accuracy: 0.4938 - val_loss: 1.2095
# Epoch 29/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - AUC: 0.7495 - accuracy: 0.4618 - loss: 1.1440 - val_AUC: 0.7268 - val_accuracy: 0.5000 - val_loss: 1.2064
# Epoch 30/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - AUC: 0.7817 - accuracy: 0.5157 - loss: 1.0723 - val_AUC: 0.7387 - val_accuracy: 0.4938 - val_loss: 1.1871
# Epoch 31/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - AUC: 0.7478 - accuracy: 0.4807 - loss: 1.1462 - val_AUC: 0.7512 - val_accuracy: 0.4938 - val_loss: 1.1715
# Epoch 32/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 170ms/step - AUC: 0.7623 - accuracy: 0.4961 - loss: 1.1279 - val_AUC: 0.7585 - val_accuracy: 0.5125 - val_loss: 1.1766
# Epoch 33/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - AUC: 0.6993 - accuracy: 0.4068 - loss: 1.1962 - val_AUC: 0.7700 - val_accuracy: 0.5375 - val_loss: 1.1819
# Epoch 34/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - AUC: 0.7489 - accuracy: 0.4815 - loss: 1.1471 - val_AUC: 0.7720 - val_accuracy: 0.5063 - val_loss: 1.1432
# Epoch 35/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - AUC: 0.7601 - accuracy: 0.4907 - loss: 1.1286 - val_AUC: 0.7831 - val_accuracy: 0.5437 - val_loss: 1.1601
# Epoch 36/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - AUC: 0.7525 - accuracy: 0.4792 - loss: 1.1436 - val_AUC: 0.7369 - val_accuracy: 0.4750 - val_loss: 1.2053
# Epoch 37/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - AUC: 0.7863 - accuracy: 0.5179 - loss: 1.0732 - val_AUC: 0.7578 - val_accuracy: 0.5500 - val_loss: 1.1524
# Epoch 38/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - AUC: 0.7829 - accuracy: 0.5030 - loss: 1.0755 - val_AUC: 0.7775 - val_accuracy: 0.5375 - val_loss: 1.1371
# Epoch 39/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - AUC: 0.7703 - accuracy: 0.4935 - loss: 1.0949 - val_AUC: 0.7813 - val_accuracy: 0.5875 - val_loss: 1.1383
# Epoch 40/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - AUC: 0.7872 - accuracy: 0.5160 - loss: 1.0465 - val_AUC: 0.7843 - val_accuracy: 0.5688 - val_loss: 1.1053
# Epoch 41/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - AUC: 0.7799 - accuracy: 0.5247 - loss: 1.1007 - val_AUC: 0.8048 - val_accuracy: 0.5813 - val_loss: 1.0910
# Epoch 42/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - AUC: 0.7960 - accuracy: 0.5325 - loss: 1.0574 - val_AUC: 0.7813 - val_accuracy: 0.5188 - val_loss: 1.1374
# Epoch 43/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - AUC: 0.7918 - accuracy: 0.5231 - loss: 1.0699 - val_AUC: 0.7923 - val_accuracy: 0.5625 - val_loss: 1.1072
# Epoch 44/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - AUC: 0.7745 - accuracy: 0.5225 - loss: 1.0827 - val_AUC: 0.8042 - val_accuracy: 0.5938 - val_loss: 1.1017
# Epoch 45/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 127ms/step - AUC: 0.7874 - accuracy: 0.5376 - loss: 1.0562 - val_AUC: 0.7981 - val_accuracy: 0.5188 - val_loss: 1.1104
# Epoch 46/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - AUC: 0.7889 - accuracy: 0.5303 - loss: 1.0558 - val_AUC: 0.7976 - val_accuracy: 0.5875 - val_loss: 1.1317
# Epoch 47/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 108ms/step - AUC: 0.7911 - accuracy: 0.5020 - loss: 1.0554 - val_AUC: 0.8078 - val_accuracy: 0.5875 - val_loss: 1.0840
# Epoch 48/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - AUC: 0.8297 - accuracy: 0.5722 - loss: 0.9728 - val_AUC: 0.7925 - val_accuracy: 0.5312 - val_loss: 1.1388
# Epoch 49/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 153ms/step - AUC: 0.7882 - accuracy: 0.5122 - loss: 1.0662 - val_AUC: 0.8076 - val_accuracy: 0.6062 - val_loss: 1.0990
# Epoch 50/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - AUC: 0.8314 - accuracy: 0.5846 - loss: 0.9694 - val_AUC: 0.7947 - val_accuracy: 0.5437 - val_loss: 1.0834
# Epoch 51/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - AUC: 0.8109 - accuracy: 0.5560 - loss: 1.0272 - val_AUC: 0.8123 - val_accuracy: 0.5875 - val_loss: 1.0640
# Epoch 52/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 145ms/step - AUC: 0.8319 - accuracy: 0.5935 - loss: 0.9726 - val_AUC: 0.8091 - val_accuracy: 0.5750 - val_loss: 1.1272
# Epoch 53/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - AUC: 0.7979 - accuracy: 0.5256 - loss: 1.0396 - val_AUC: 0.8050 - val_accuracy: 0.5625 - val_loss: 1.0982
# Epoch 54/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 151ms/step - AUC: 0.8170 - accuracy: 0.5672 - loss: 0.9981 - val_AUC: 0.8175 - val_accuracy: 0.5875 - val_loss: 1.0824
# Epoch 55/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - AUC: 0.7974 - accuracy: 0.5171 - loss: 1.0335 - val_AUC: 0.8092 - val_accuracy: 0.5625 - val_loss: 1.0679
# Epoch 56/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - AUC: 0.8181 - accuracy: 0.5964 - loss: 1.0012 - val_AUC: 0.8117 - val_accuracy: 0.6000 - val_loss: 1.0837
# Epoch 57/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step - AUC: 0.8345 - accuracy: 0.5941 - loss: 0.9474 - val_AUC: 0.8161 - val_accuracy: 0.5813 - val_loss: 1.0567
# Epoch 58/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - AUC: 0.8266 - accuracy: 0.5902 - loss: 0.9733 - val_AUC: 0.8179 - val_accuracy: 0.5750 - val_loss: 1.0502
# Epoch 59/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - AUC: 0.8185 - accuracy: 0.5603 - loss: 1.0145 - val_AUC: 0.8132 - val_accuracy: 0.5938 - val_loss: 1.0830
# Epoch 60/60
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - AUC: 0.8215 - accuracy: 0.5824 - loss: 0.9967 - val_AUC: 0.8249 - val_accuracy: 0.6062 - val_loss: 1.0290
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - AUC: 0.8731 - accuracy: 0.6380 - loss: 0.9288
# Test accuracy: 65.75%
# Test AUC: 87.36%

# %%
# ===== Grad-CAM utils (reference) =====
def get_img_array(img):
    array = keras.preprocessing.image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

def gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = tf.keras.models.Model(
        [model.input], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        last_conv_layer_output, preds = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(preds[0])
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, last_conv_layer_output)
    # As in reference: global-average over patch/channel dims
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1))
    last_conv_layer_output = last_conv_layer_output
    heatmap = last_conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_gradcam(img, heatmap, alpha=0.4, preds=None, plot=None):
    if preds is None:
        preds = [0.0]*len(class_names)
    # Rescale to 0..255
    heatmap_uint8 = np.uint8(255 * heatmap)
    jet = cm.get_cmap("jet")
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap_uint8]
    jet_heatmap = keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = keras.preprocessing.image.img_to_array(jet_heatmap)

    # Superimpose
    superimposed_img = jet_heatmap * alpha + img
    superimposed_img = keras.preprocessing.image.array_to_img(superimposed_img)

    if plot is None:
        plt.figure(figsize=(5,5))
        ax = plt.gca()
    else:
        ax = plot
    ax.imshow(superimposed_img)
    # Simple title with first two probs if available
    try:
        title_probs = " | ".join([f"{cls}:{preds[i]:.3f}" for i, cls in enumerate(class_names[:min(2,len(class_names))])])
    except Exception:
        title_probs = ""
    ax.set_title(title_probs)
    ax.axis("off")

# %%
# ===== Grad-CAM demo on a few test images =====
# NOTE: run training first or load your trained weights into vit_classifier before running this.

last_conv_layer_name = "layer_normalization"  # from reference

# Take one batch from test_loader
test_batch_images, test_batch_labels = next(iter(test_loader))

fig, axes = plt.subplots(2, 3, figsize=(14, 9))
axes = axes.ravel()

for idx, ax in enumerate(axes):
    if idx >= len(test_batch_images):
        break
    img = test_batch_images[idx].numpy().astype("uint8")
    img_array = np.expand_dims(img, axis=0)
    # Make sure last layer's activation is linear for Grad-CAM step as in reference
    vit_classifier.layers[-1].activation = None
    preds = vit_classifier.predict(img_array, verbose=0)
    heatmap = gradcam_heatmap(img_array, vit_classifier, last_conv_layer_name)
    heatmap = np.reshape(heatmap, (image_size // patch_size, image_size // patch_size))
    display_gradcam(img, heatmap, preds=preds[0], plot=ax)

plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
